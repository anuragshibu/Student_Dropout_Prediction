# %%
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
df = pd.read_csv('d1.csv')
df.head()
df.dropna(inplace = True)

# %%
df
# Out:
#       AGE SCHOOL TYPE GENDER CASTE  FAMILY INCOME  OCCUPATION MARRIED(YES/NO)  \
# 0      17        GOVT      M   OBC          84516      LABOUR             YES
# 1      17        GOVT      F   GEN         140148  ACCOUNTANT             YES
# 2      16         PVT      F   GEN         108848  ACCOUNTANT              NO
# 3      18        GOVT      F   GEN          94785      OTHERS              NO
# 4      12        GOVT      F   OBC          90919     TEACHER              NO
# ...   ...         ...    ...   ...            ...         ...             ...
# 4995   10        GOVT      M    ST          59000      LABOUR             YES
# 4996   18         PVT      F   GEN         119498  ACCOUNTANT              NO
# 4997   15        GOVT      M    SC          73176      LABOUR              NO
# 4998   13        GOVT      M    SC          70585      LABOUR              NO
# 4999   17         PVT      F   GEN          97387    BUSINESS             YES
#
# ...

# %%
df.shape
# Out:
# (5000, 13)

# %%
le = preprocessing.LabelEncoder()
le
# Out:
# LabelEncoder()

# %%
df['Encoded_Gender'] = le.fit_transform(df['GENDER'])
data = 0
label_mapping.get(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [589], line 2
#       1 df['Encoded_Gender'] = le.fit_transform(df['GENDER'])
# ----> 2 label_mapping.get(0)
#
# NameError: name 'label_mapping' is not defined

# %%
df.drop(columns= 'GENDER',inplace = True)
df
# Out:
#       AGE SCHOOL TYPE CASTE  FAMILY INCOME  OCCUPATION MARRIED(YES/NO)  \
# 0      17        GOVT   OBC          84516      LABOUR             YES
# 1      17        GOVT   GEN         140148  ACCOUNTANT             YES
# 2      16         PVT   GEN         108848  ACCOUNTANT              NO
# 3      18        GOVT   GEN          94785      OTHERS              NO
# 4      12        GOVT   OBC          90919     TEACHER              NO
# ...   ...         ...   ...            ...         ...             ...
# 4995   10        GOVT    ST          59000      LABOUR             YES
# 4996   18         PVT   GEN         119498  ACCOUNTANT              NO
# 4997   15        GOVT    SC          73176      LABOUR              NO
# 4998   13        GOVT    SC          70585      LABOUR              NO
# 4999   17         PVT   GEN          97387    BUSINESS             YES
#
#       ACADEMIC MARKS  NO OF SIBLINGS WORK(YES/NO)  CLASS LOCATION DROPOUT  \
# ...

# %%
df['Encoded_School_Type'] = le.fit_transform(df['SCHOOL TYPE'])
df
# Out:
#       AGE SCHOOL TYPE CASTE  FAMILY INCOME  OCCUPATION MARRIED(YES/NO)  \
# 0      17        GOVT   OBC          84516      LABOUR             YES
# 1      17        GOVT   GEN         140148  ACCOUNTANT             YES
# 2      16         PVT   GEN         108848  ACCOUNTANT              NO
# 3      18        GOVT   GEN          94785      OTHERS              NO
# 4      12        GOVT   OBC          90919     TEACHER              NO
# ...   ...         ...   ...            ...         ...             ...
# 4995   10        GOVT    ST          59000      LABOUR             YES
# 4996   18         PVT   GEN         119498  ACCOUNTANT              NO
# 4997   15        GOVT    SC          73176      LABOUR              NO
# 4998   13        GOVT    SC          70585      LABOUR              NO
# 4999   17         PVT   GEN          97387    BUSINESS             YES
#
#       ACADEMIC MARKS  NO OF SIBLINGS WORK(YES/NO)  CLASS LOCATION DROPOUT  \
# ...

# %%
df['Encoded_Occupation'] = le.fit_transform(df['OCCUPATION'])
df
# Out:
#       AGE SCHOOL TYPE CASTE  FAMILY INCOME  OCCUPATION MARRIED(YES/NO)  \
# 0      17        GOVT   OBC          84516      LABOUR             YES
# 1      17        GOVT   GEN         140148  ACCOUNTANT             YES
# 2      16         PVT   GEN         108848  ACCOUNTANT              NO
# 3      18        GOVT   GEN          94785      OTHERS              NO
# 4      12        GOVT   OBC          90919     TEACHER              NO
# ...   ...         ...   ...            ...         ...             ...
# 4995   10        GOVT    ST          59000      LABOUR             YES
# 4996   18         PVT   GEN         119498  ACCOUNTANT              NO
# 4997   15        GOVT    SC          73176      LABOUR              NO
# 4998   13        GOVT    SC          70585      LABOUR              NO
# 4999   17         PVT   GEN          97387    BUSINESS             YES
#
#       ACADEMIC MARKS  NO OF SIBLINGS WORK(YES/NO)  CLASS LOCATION DROPOUT  \
# ...

# %%
df['Encoded_Married'] = le.fit_transform(df['MARRIED(YES/NO)'])
df
# Out:
#       AGE SCHOOL TYPE CASTE  FAMILY INCOME  OCCUPATION MARRIED(YES/NO)  \
# 0      17        GOVT   OBC          84516      LABOUR             YES
# 1      17        GOVT   GEN         140148  ACCOUNTANT             YES
# 2      16         PVT   GEN         108848  ACCOUNTANT              NO
# 3      18        GOVT   GEN          94785      OTHERS              NO
# 4      12        GOVT   OBC          90919     TEACHER              NO
# ...   ...         ...   ...            ...         ...             ...
# 4995   10        GOVT    ST          59000      LABOUR             YES
# 4996   18         PVT   GEN         119498  ACCOUNTANT              NO
# 4997   15        GOVT    SC          73176      LABOUR              NO
# 4998   13        GOVT    SC          70585      LABOUR              NO
# 4999   17         PVT   GEN          97387    BUSINESS             YES
#
#       ACADEMIC MARKS  NO OF SIBLINGS WORK(YES/NO)  CLASS LOCATION DROPOUT  \
# ...

# %%
df['Encoded_Dropout'] = le.fit_transform(df['DROPOUT'])
df
# Out:
#       AGE SCHOOL TYPE CASTE  FAMILY INCOME  OCCUPATION MARRIED(YES/NO)  \
# 0      17        GOVT   OBC          84516      LABOUR             YES
# 1      17        GOVT   GEN         140148  ACCOUNTANT             YES
# 2      16         PVT   GEN         108848  ACCOUNTANT              NO
# 3      18        GOVT   GEN          94785      OTHERS              NO
# 4      12        GOVT   OBC          90919     TEACHER              NO
# ...   ...         ...   ...            ...         ...             ...
# 4995   10        GOVT    ST          59000      LABOUR             YES
# 4996   18         PVT   GEN         119498  ACCOUNTANT              NO
# 4997   15        GOVT    SC          73176      LABOUR              NO
# 4998   13        GOVT    SC          70585      LABOUR              NO
# 4999   17         PVT   GEN          97387    BUSINESS             YES
#
#       ACADEMIC MARKS  NO OF SIBLINGS WORK(YES/NO)  CLASS LOCATION DROPOUT  \
# ...

# %%
df['Encoded_Work'] = le.fit_transform(df['WORK(YES/NO)'])
df.head()
# Out:
#    AGE SCHOOL TYPE CASTE  FAMILY INCOME  OCCUPATION MARRIED(YES/NO)  \
# 0   17        GOVT   OBC          84516      LABOUR             YES
# 1   17        GOVT   GEN         140148  ACCOUNTANT             YES
# 2   16         PVT   GEN         108848  ACCOUNTANT              NO
# 3   18        GOVT   GEN          94785      OTHERS              NO
# 4   12        GOVT   OBC          90919     TEACHER              NO
#
#    ACADEMIC MARKS  NO OF SIBLINGS WORK(YES/NO)  CLASS LOCATION DROPOUT  \
# 0              55               2          YES      4    RURAL       Y
# 1              81               3           NO     10    RURAL       Y
# 2              62               3           NO      8    URBAN       N
# 3              76               2           NO     10    RURAL       Y
# 4              65               3          YES      3    RURAL       Y
#
#    Encoded_Gender  Encoded_School_Type  Encoded_Occupation  Encoded_Married  \
# ...

# %%
df['Encoded_Location'] = le.fit_transform(df['LOCATION'])
df.sample(5)
# Out:
#       AGE SCHOOL TYPE CASTE  FAMILY INCOME  OCCUPATION MARRIED(YES/NO)  \
# 1529   17         PVT   GEN         300000    BUSINESS              NO
# 2054   14        GOVT   OBC         107924      LABOUR              NO
# 1579   18         PVT   GEN         300000  ACCOUNTANT              NO
# 3460   17         PVT   GEN         300000  ACCOUNTANT              NO
# 1746   13        GOVT    SC          93980      LABOUR              NO
#
#       ACADEMIC MARKS  NO OF SIBLINGS WORK(YES/NO)  CLASS LOCATION DROPOUT  \
# 1529              86               1          YES     10    URBAN       N
# 2054              55               4          YES      3    RURAL       Y
# 1579              84               1           NO     11    RURAL       N
# 3460              84               3           NO     10    URBAN       N
# 1746              58               5          YES      3    RURAL       Y
#
#       Encoded_Gender  Encoded_School_Type  Encoded_Occupation  \
# ...

# %%
df['Encoced_Caste'] = le.fit_transform(df['CASTE'])
df
# Out:
#       AGE SCHOOL TYPE CASTE  FAMILY INCOME  OCCUPATION MARRIED(YES/NO)  \
# 0      17        GOVT   OBC          84516      LABOUR             YES
# 1      17        GOVT   GEN         140148  ACCOUNTANT             YES
# 2      16         PVT   GEN         108848  ACCOUNTANT              NO
# 3      18        GOVT   GEN          94785      OTHERS              NO
# 4      12        GOVT   OBC          90919     TEACHER              NO
# ...   ...         ...   ...            ...         ...             ...
# 4995   10        GOVT    ST          59000      LABOUR             YES
# 4996   18         PVT   GEN         119498  ACCOUNTANT              NO
# 4997   15        GOVT    SC          73176      LABOUR              NO
# 4998   13        GOVT    SC          70585      LABOUR              NO
# 4999   17         PVT   GEN          97387    BUSINESS             YES
#
#       ACADEMIC MARKS  NO OF SIBLINGS WORK(YES/NO)  CLASS LOCATION DROPOUT  \
# ...

# %%
df.head()
# Out:
#    AGE SCHOOL TYPE CASTE  FAMILY INCOME  OCCUPATION MARRIED(YES/NO)  \
# 0   17        GOVT   OBC          84516      LABOUR             YES
# 1   17        GOVT   GEN         140148  ACCOUNTANT             YES
# 2   16         PVT   GEN         108848  ACCOUNTANT              NO
# 3   18        GOVT   GEN          94785      OTHERS              NO
# 4   12        GOVT   OBC          90919     TEACHER              NO
#
#    ACADEMIC MARKS  NO OF SIBLINGS WORK(YES/NO)  CLASS LOCATION DROPOUT  \
# 0              55               2          YES      4    RURAL       Y
# 1              81               3           NO     10    RURAL       Y
# 2              62               3           NO      8    URBAN       N
# 3              76               2           NO     10    RURAL       Y
# 4              65               3          YES      3    RURAL       Y
#
#    Encoded_Gender  Encoded_School_Type  Encoded_Occupation  Encoded_Married  \
# ...

# %%
X =df[['AGE','FAMILY INCOME','ACADEMIC MARKS','NO OF SIBLINGS','CLASS','Encoded_Gender','Encoded_School_Type','Encoded_Occupation','Encoded_Married','Encoded_Work','Encoded_Location','Encoced_Caste']]

X
# Out:
#       AGE  FAMILY INCOME  ACADEMIC MARKS  NO OF SIBLINGS  CLASS  \
# 0      17          84516              55               2      4
# 1      17         140148              81               3     10
# 2      16         108848              62               3      8
# 3      18          94785              76               2     10
# 4      12          90919              65               3      3
# ...   ...            ...             ...             ...    ...
# 4995   10          59000              55               5      3
# 4996   18         119498              86               1      9
# 4997   15          73176              61               3      6
# 4998   13          70585              55               4      4
# 4999   17          97387              75               4      4
#
#       Encoded_Gender  Encoded_School_Type  Encoded_Occupation  \
# 0                  1                    0                   3
# 1                  0                    0                   0
# ...

# %%
y = df[['Encoded_Dropout']]
y.head()
# Out:
#    Encoded_Dropout
# 0                1
# 1                1
# 2                0
# 3                1
# 4                1

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size = 0.3)

# %%
len(x_train)
# Out:
# 3500

# %%
x_train
# Out:
#       AGE  FAMILY INCOME  ACADEMIC MARKS  NO OF SIBLINGS  CLASS  \
# 4043   13          59000              76               4      3
# 3072   18         282640              82               1      9
# 3092   12         100000              57               2     10
# 3962   18         114572              62               1      9
# 2081   13          93575              65               5      4
# ...   ...            ...             ...             ...    ...
# 2844   15          85973              70               3      4
# 877    12          72924              64               5      3
# 3097   18         269428              84               2      9
# 4099   14          93725              68               3      3
# 4995   10          59000              55               5      3
#
#       Encoded_Gender  Encoded_School_Type  Encoded_Occupation  \
# 4043               1                    0                   5
# 3072               0                    1                   5
# ...

# %%
nv = GaussianNB()
nv
# Out:
# GaussianNB()

# %%
nv.fit(x_train,y_train)
# Out:
# C:\python\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GaussianNB()

# %%
nv.predict(x_test)
# Out:
# array([1, 0, 1, ..., 1, 1, 1])

# %%
nv.score(x_test,y_test)
# Out:
# 0.826

# %%
inp = {'AGE': [11,12],'FAMILY INCOME':[90000,500000],'ACADEMIC MARKS':[80,83],'NO OF SIBLINGS':[2,1],'CLASS':[10,5],'Encoded_Gender':[1,0],'Encoded_School_Type':[1,1],'Encoded_Occupation':[3,2],'Encoded_Married':[1,0],'Encoded_Work':[0,0],'Encoded_Location':[1,0],'Encoced_Caste':[2,1]}
inp = pd.DataFrame(inp)
inp
# Out:
#    AGE  FAMILY INCOME  ACADEMIC MARKS  NO OF SIBLINGS  CLASS  Encoded_Gender  \
# 0   11          90000              80               2     10               1
# 1   12         500000              83               1      5               0
#
#    Encoded_School_Type  Encoded_Occupation  Encoded_Married  Encoded_Work  \
# 0                    1                   3                1             0
# 1                    1                   2                0             0
#
#    Encoded_Location  Encoced_Caste
# 0                 1              2
# 1                 0              1

# %%
nv.predict(inp)
# Out:
# array([1, 0])

# %%
pickle.dump(nv,open('model1.pkl','wb'))

# %%
inp = [[11,90000,80,2,10,1,1,1,3,1,3,1]]
inp
# Out:
# [[11, 90000, 80, 2, 10, 1, 1, 1, 3, 1, 3, 1]]

# %%
nv.predict(inp)
# Out:
# C:\python\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# array([1])

# %%
t = x['Encoded_Gender'].unique()
le.inverse_transform(t)
# Out:
# array(['OBC', 'GEN'], dtype=object)
